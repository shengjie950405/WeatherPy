# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 727

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=235df60ea2cb0dc229bbd426b922e5d8

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"] 

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taburi
# City not found. Skipping...
# Processing Record 2 of Set 1 | newport
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | phillaur
# Processing Record 6 of Set 1 | chuy
# Processing Record 7 of Set 1 | viedma
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | ocos
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | cabo san lucas
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | pagudpud
# Processing Record 18 of Set 1 | puerto madryn
# Processing Record 19 of Set 1 | rokytne
# Processing Record 20 of Set 1 | tuatapere
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | quatre cocos
# Processing Record 25 of Set 1 | tripoli
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | moussoro
# Processing Record 29 of Set 1 | marsa matruh
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | pangoa
# Processing Record 32 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 1 | caravelas
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | north bend
# Processing Record 38 of Set 1 | lompoc
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | lufilufi
# Processing Record 41 of Set 1 | svobodnyy
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | yumen
# Processing Record 44 of Set 1 | fremont
# Processing Record 45 of Set 1 | srednekolymsk
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | beringovskiy
# Processing Record 48 of Set 1 | chokwe
# Processing Record 49 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 1 | pervomayskoye
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | chokurdakh
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | kavaratti
# Processing Record 5 of Set 2 | sao joao da barra
# Processing Record 6 of Set 2 | manokwari
# Processing Record 7 of Set 2 | norman wells
# Processing Record 8 of Set 2 | khatanga
# Processing Record 9 of Set 2 | ranong
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | abnub
# Processing Record 12 of Set 2 | lagoa
# Processing Record 13 of Set 2 | constitucion
# Processing Record 14 of Set 2 | nivala
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | bengkulu
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | lavrentiya
# Processing Record 19 of Set 2 | bilibino
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | mehamn
# Processing Record 22 of Set 2 | katsuura
# Processing Record 23 of Set 2 | vryburg
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | ponta do sol
# Processing Record 27 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 2 | hithadhoo
# Processing Record 29 of Set 2 | bassila
# Processing Record 30 of Set 2 | tangping
# Processing Record 31 of Set 2 | kahului
# Processing Record 32 of Set 2 | solsvik
# City not found. Skipping...
# Processing Record 33 of Set 2 | talnakh
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | narsaq
# Processing Record 37 of Set 2 | tartki
# City not found. Skipping...
# Processing Record 38 of Set 2 | gualeguaychu
# Processing Record 39 of Set 2 | san vito
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | marsala
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | yar-sale
# Processing Record 44 of Set 2 | san jeronimo
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | omsukchan
# Processing Record 47 of Set 2 | victoria point
# Processing Record 48 of Set 2 | ihosy
# Processing Record 49 of Set 2 | saskylakh
# Processing Record 50 of Set 2 | susangerd
# Processing Record 1 of Set 3 | tsiroanomandidy
# Processing Record 2 of Set 3 | camana
# Processing Record 3 of Set 3 | bisert
# Processing Record 4 of Set 3 | port augusta
# Processing Record 5 of Set 3 | saldanha
# Processing Record 6 of Set 3 | sitka
# Processing Record 7 of Set 3 | port hardy
# Processing Record 8 of Set 3 | saryozek
# Processing Record 9 of Set 3 | martil
# Processing Record 10 of Set 3 | butaritari
# Processing Record 11 of Set 3 | dingle
# Processing Record 12 of Set 3 | ahar
# Processing Record 13 of Set 3 | comodoro rivadavia
# Processing Record 14 of Set 3 | padang
# Processing Record 15 of Set 3 | terney
# Processing Record 16 of Set 3 | yambio
# Processing Record 17 of Set 3 | nabire
# Processing Record 18 of Set 3 | yining
# Processing Record 19 of Set 3 | dakar
# Processing Record 20 of Set 3 | swellendam
# Processing Record 21 of Set 3 | quelimane
# Processing Record 22 of Set 3 | nome
# Processing Record 23 of Set 3 | ahmadpur
# Processing Record 24 of Set 3 | outlook
# Processing Record 25 of Set 3 | waddan
# Processing Record 26 of Set 3 | labuhan
# Processing Record 27 of Set 3 | mount barker
# Processing Record 28 of Set 3 | pimentel
# Processing Record 29 of Set 3 | port-gentil
# Processing Record 30 of Set 3 | lamu
# Processing Record 31 of Set 3 | kodiak
# Processing Record 32 of Set 3 | aklavik
# Processing Record 33 of Set 3 | lasa
# Processing Record 34 of Set 3 | lucea
# Processing Record 35 of Set 3 | ayan
# Processing Record 36 of Set 3 | puerto ayora
# Processing Record 37 of Set 3 | antalaha
# Processing Record 38 of Set 3 | le port
# Processing Record 39 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 3 | canyon
# Processing Record 41 of Set 3 | ecublens
# Processing Record 42 of Set 3 | bara
# Processing Record 43 of Set 3 | killarney
# Processing Record 44 of Set 3 | zhezkazgan
# Processing Record 45 of Set 3 | pavlovsk
# Processing Record 46 of Set 3 | tuktoyaktuk
# Processing Record 47 of Set 3 | barrow
# Processing Record 48 of Set 3 | beloha
# Processing Record 49 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 3 | ninghai
# Processing Record 1 of Set 4 | touros
# Processing Record 2 of Set 4 | ulladulla
# Processing Record 3 of Set 4 | el alto
# Processing Record 4 of Set 4 | rio grande
# Processing Record 5 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 4 | changde
# Processing Record 7 of Set 4 | la ronge
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | aitape
# Processing Record 10 of Set 4 | acapulco
# Processing Record 11 of Set 4 | bandar-e lengeh
# Processing Record 12 of Set 4 | valparaiso
# Processing Record 13 of Set 4 | goderich
# Processing Record 14 of Set 4 | haines junction
# Processing Record 15 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 4 | bathsheba
# Processing Record 17 of Set 4 | molaoi
# Processing Record 18 of Set 4 | waipawa
# Processing Record 19 of Set 4 | esperance
# Processing Record 20 of Set 4 | jiamusi
# Processing Record 21 of Set 4 | ancud
# Processing Record 22 of Set 4 | rapid valley
# Processing Record 23 of Set 4 | bembereke
# Processing Record 24 of Set 4 | haapu
# City not found. Skipping...
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | necochea
# Processing Record 27 of Set 4 | buon me thuot
# City not found. Skipping...
# Processing Record 28 of Set 4 | brandon
# Processing Record 29 of Set 4 | nikolskoye
# Processing Record 30 of Set 4 | axim
# Processing Record 31 of Set 4 | ahipara
# Processing Record 32 of Set 4 | pisco
# Processing Record 33 of Set 4 | ribeira grande
# Processing Record 34 of Set 4 | piracanjuba
# Processing Record 35 of Set 4 | cazaje
# City not found. Skipping...
# Processing Record 36 of Set 4 | sioux lookout
# Processing Record 37 of Set 4 | barahona
# Processing Record 38 of Set 4 | nanortalik
# Processing Record 39 of Set 4 | anchorage
# Processing Record 40 of Set 4 | bilma
# Processing Record 41 of Set 4 | yelets
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | nizhniy kuranakh
# Processing Record 44 of Set 4 | manzil tamim
# City not found. Skipping...
# Processing Record 45 of Set 4 | jiaocheng
# Processing Record 46 of Set 4 | suba
# Processing Record 47 of Set 4 | alta floresta
# Processing Record 48 of Set 4 | half moon bay
# Processing Record 49 of Set 4 | port lincoln
# Processing Record 50 of Set 4 | luderitz
# Processing Record 1 of Set 5 | tual
# Processing Record 2 of Set 5 | coquimbo
# Processing Record 3 of Set 5 | calatagan
# Processing Record 4 of Set 5 | rognan
# Processing Record 5 of Set 5 | manzanillo
# Processing Record 6 of Set 5 | kota kinabalu
# Processing Record 7 of Set 5 | hameenlinna
# Processing Record 8 of Set 5 | kyra
# Processing Record 9 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 5 | lebu
# Processing Record 11 of Set 5 | sobolevo
# Processing Record 12 of Set 5 | bima
# Processing Record 13 of Set 5 | lahad datu
# Processing Record 14 of Set 5 | bluffton
# Processing Record 15 of Set 5 | bentiu
# Processing Record 16 of Set 5 | gualaceo
# Processing Record 17 of Set 5 | avera
# Processing Record 18 of Set 5 | charters towers
# Processing Record 19 of Set 5 | winnemucca
# Processing Record 20 of Set 5 | nouadhibou
# Processing Record 21 of Set 5 | mar del plata
# Processing Record 22 of Set 5 | severo-kurilsk
# Processing Record 23 of Set 5 | vagay
# Processing Record 24 of Set 5 | bousso
# Processing Record 25 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 5 | san patricio
# Processing Record 27 of Set 5 | ewo
# Processing Record 28 of Set 5 | osakarovka
# Processing Record 29 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 5 | georgetown
# Processing Record 31 of Set 5 | aguadilla
# Processing Record 32 of Set 5 | imeni zhelyabova
# Processing Record 33 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 5 | ayia galini
# Processing Record 35 of Set 5 | talakan
# Processing Record 36 of Set 5 | olinda
# Processing Record 37 of Set 5 | lorengau
# Processing Record 38 of Set 5 | gurupa
# Processing Record 39 of Set 5 | dunedin
# Processing Record 40 of Set 5 | ugoofaaru
# Processing Record 41 of Set 5 | faya
# Processing Record 42 of Set 5 | victoria
# Processing Record 43 of Set 5 | udachnyy
# Processing Record 44 of Set 5 | murmashi
# Processing Record 45 of Set 5 | morondava
# Processing Record 46 of Set 5 | gornopravdinsk
# Processing Record 47 of Set 5 | lata
# Processing Record 48 of Set 5 | gweta
# Processing Record 49 of Set 5 | boueni
# Processing Record 50 of Set 5 | shihezi
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | geraldton
# Processing Record 3 of Set 6 | erzin
# Processing Record 4 of Set 6 | saint-pierre
# Processing Record 5 of Set 6 | canutama
# Processing Record 6 of Set 6 | porto novo
# Processing Record 7 of Set 6 | tasiilaq
# Processing Record 8 of Set 6 | zharkent
# Processing Record 9 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 10 of Set 6 | vostok
# Processing Record 11 of Set 6 | ordzhonikidze
# Processing Record 12 of Set 6 | west bay
# Processing Record 13 of Set 6 | cidreira
# Processing Record 14 of Set 6 | roma
# Processing Record 15 of Set 6 | meulaboh
# Processing Record 16 of Set 6 | gorontalo
# Processing Record 17 of Set 6 | yulara
# Processing Record 18 of Set 6 | marawi
# Processing Record 19 of Set 6 | hurghada
# Processing Record 20 of Set 6 | chongqing
# Processing Record 21 of Set 6 | kokopo
# Processing Record 22 of Set 6 | torbay
# Processing Record 23 of Set 6 | hualmay
# Processing Record 24 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 6 | dauphin
# Processing Record 26 of Set 6 | okhotsk
# Processing Record 27 of Set 6 | zhigansk
# Processing Record 28 of Set 6 | kichera
# Processing Record 29 of Set 6 | dzhebariki-khaya
# Processing Record 30 of Set 6 | hobyo
# Processing Record 31 of Set 6 | yuli
# Processing Record 32 of Set 6 | yueyang
# Processing Record 33 of Set 6 | una
# Processing Record 34 of Set 6 | hofn
# Processing Record 35 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 6 | jiehu
# Processing Record 38 of Set 6 | aneho
# Processing Record 39 of Set 6 | codrington
# Processing Record 40 of Set 6 | bushehr
# Processing Record 41 of Set 6 | young
# Processing Record 42 of Set 6 | itoman
# Processing Record 43 of Set 6 | san juan
# Processing Record 44 of Set 6 | dalvik
# Processing Record 45 of Set 6 | fort nelson
# Processing Record 46 of Set 6 | flinders
# Processing Record 47 of Set 6 | guarapari
# Processing Record 48 of Set 6 | jiuquan
# Processing Record 49 of Set 6 | gizo
# Processing Record 50 of Set 6 | ferme-neuve
# Processing Record 1 of Set 7 | kaitangata
# Processing Record 2 of Set 7 | raudeberg
# Processing Record 3 of Set 7 | hamilton
# Processing Record 4 of Set 7 | krasnyy chikoy
# Processing Record 5 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 7 | fairbanks
# Processing Record 7 of Set 7 | xadani
# City not found. Skipping...
# Processing Record 8 of Set 7 | khorixas
# Processing Record 9 of Set 7 | lima
# Processing Record 10 of Set 7 | pevek
# Processing Record 11 of Set 7 | the pas
# Processing Record 12 of Set 7 | priargunsk
# Processing Record 13 of Set 7 | husavik
# Processing Record 14 of Set 7 | mana
# Processing Record 15 of Set 7 | tambacounda
# Processing Record 16 of Set 7 | ostrovnoy
# Processing Record 17 of Set 7 | mackay
# Processing Record 18 of Set 7 | gawler
# Processing Record 19 of Set 7 | pringsewu
# Processing Record 20 of Set 7 | mount gambier
# Processing Record 21 of Set 7 | san policarpo
# Processing Record 22 of Set 7 | pangnirtung
# Processing Record 23 of Set 7 | kempele
# Processing Record 24 of Set 7 | fortuna
# Processing Record 25 of Set 7 | russell
# Processing Record 26 of Set 7 | severo-yeniseyskiy
# Processing Record 27 of Set 7 | taoudenni
# Processing Record 28 of Set 7 | pudozh
# Processing Record 29 of Set 7 | tacuati
# Processing Record 30 of Set 7 | mogadishu
# Processing Record 31 of Set 7 | chabua
# Processing Record 32 of Set 7 | hvammstangi
# City not found. Skipping...
# Processing Record 33 of Set 7 | hasaki
# Processing Record 34 of Set 7 | la libertad
# Processing Record 35 of Set 7 | bukama
# Processing Record 36 of Set 7 | souillac
# Processing Record 37 of Set 7 | colares
# Processing Record 38 of Set 7 | bethel
# Processing Record 39 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 40 of Set 7 | saint anthony
# Processing Record 41 of Set 7 | faanui
# Processing Record 42 of Set 7 | warmbad
# Processing Record 43 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 7 | bambous virieux
# Processing Record 45 of Set 7 | belomorsk
# Processing Record 46 of Set 7 | bambanglipuro
# Processing Record 47 of Set 7 | jumla
# Processing Record 48 of Set 7 | oistins
# Processing Record 49 of Set 7 | yenagoa
# Processing Record 50 of Set 7 | grao mogol
# Processing Record 1 of Set 8 | verkh-usugli
# Processing Record 2 of Set 8 | byron bay
# Processing Record 3 of Set 8 | cherskiy
# Processing Record 4 of Set 8 | dzilam gonzalez
# Processing Record 5 of Set 8 | san rafael
# Processing Record 6 of Set 8 | bhanpura
# Processing Record 7 of Set 8 | provideniya
# Processing Record 8 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 9 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 8 | pasni
# Processing Record 11 of Set 8 | preston
# Processing Record 12 of Set 8 | longyearbyen
# Processing Record 13 of Set 8 | vila velha
# Processing Record 14 of Set 8 | straubing
# Processing Record 15 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 16 of Set 8 | kodinsk
# Processing Record 17 of Set 8 | sredniy ikorets
# Processing Record 18 of Set 8 | brae
# Processing Record 19 of Set 8 | geilo
# Processing Record 20 of Set 8 | aasiaat
# Processing Record 21 of Set 8 | warrnambool
# Processing Record 22 of Set 8 | lunenburg
# Processing Record 23 of Set 8 | ust-koksa
# Processing Record 24 of Set 8 | verkhniye tatyshly
# Processing Record 25 of Set 8 | anori
# Processing Record 26 of Set 8 | college
# Processing Record 27 of Set 8 | bundaberg
# Processing Record 28 of Set 8 | warah
# Processing Record 29 of Set 8 | japura
# Processing Record 30 of Set 8 | adrar
# Processing Record 31 of Set 8 | miraflores
# Processing Record 32 of Set 8 | guiratinga
# Processing Record 33 of Set 8 | dicabisagan
# Processing Record 34 of Set 8 | newtownards
# Processing Record 35 of Set 8 | dhidhdhoo
# Processing Record 36 of Set 8 | vestmannaeyjar
# Processing Record 37 of Set 8 | teguise
# Processing Record 38 of Set 8 | sangar
# Processing Record 39 of Set 8 | bani
# Processing Record 40 of Set 8 | surt
# Processing Record 41 of Set 8 | corn island
# Processing Record 42 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 43 of Set 8 | stephenville
# Processing Record 44 of Set 8 | basco
# Processing Record 45 of Set 8 | warwick
# Processing Record 46 of Set 8 | bayan
# Processing Record 47 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 8 | iquique
# Processing Record 49 of Set 8 | lalibela
# Processing Record 50 of Set 8 | sampit
# Processing Record 1 of Set 9 | petatlan
# Processing Record 2 of Set 9 | barra do garcas
# Processing Record 3 of Set 9 | jubayl
# City not found. Skipping...
# Processing Record 4 of Set 9 | gravdal
# Processing Record 5 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 9 | qitaihe
# Processing Record 7 of Set 9 | timra
# Processing Record 8 of Set 9 | alofi
# Processing Record 9 of Set 9 | ust-nera
# Processing Record 10 of Set 9 | olafsvik
# Processing Record 11 of Set 9 | nushki
# Processing Record 12 of Set 9 | batouri
# Processing Record 13 of Set 9 | yerbogachen
# Processing Record 14 of Set 9 | safranbolu
# Processing Record 15 of Set 9 | abu samrah
# Processing Record 16 of Set 9 | sept-iles
# Processing Record 17 of Set 9 | pemangkat
# Processing Record 18 of Set 9 | huaraz
# Processing Record 19 of Set 9 | lincoln
# Processing Record 20 of Set 9 | rondonopolis
# Processing Record 21 of Set 9 | igrim
# Processing Record 22 of Set 9 | kakonko
# Processing Record 23 of Set 9 | saint george
# Processing Record 24 of Set 9 | maniitsoq
# Processing Record 25 of Set 9 | tazovskiy
# Processing Record 26 of Set 9 | vila franca do campo
# Processing Record 27 of Set 9 | alice springs
# Processing Record 28 of Set 9 | hemsedal
# Processing Record 29 of Set 9 | kamenka
# Processing Record 30 of Set 9 | airai
# Processing Record 31 of Set 9 | troyes
# Processing Record 32 of Set 9 | ostrovskoye
# Processing Record 33 of Set 9 | evensk
# Processing Record 34 of Set 9 | kalemie
# Processing Record 35 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 9 | that phanom
# Processing Record 37 of Set 9 | xiaoweizhai
# Processing Record 38 of Set 9 | kangaatsiaq
# Processing Record 39 of Set 9 | maputo
# Processing Record 40 of Set 9 | suraabad
# Processing Record 41 of Set 9 | vila do maio
# Processing Record 42 of Set 9 | anadyr
# Processing Record 43 of Set 9 | honiara
# Processing Record 44 of Set 9 | kajaani
# Processing Record 45 of Set 9 | robinson
# Processing Record 46 of Set 9 | taltal
# Processing Record 47 of Set 9 | hovd
# Processing Record 48 of Set 9 | meadow lake
# Processing Record 49 of Set 9 | barinas
# Processing Record 50 of Set 9 | bichena
# Processing Record 1 of Set 10 | sao paulo de olivenca
# Processing Record 2 of Set 10 | bud
# Processing Record 3 of Set 10 | henties bay
# Processing Record 4 of Set 10 | neyshabur
# Processing Record 5 of Set 10 | northam
# Processing Record 6 of Set 10 | strezhevoy
# Processing Record 7 of Set 10 | tigil
# Processing Record 8 of Set 10 | pierre
# Processing Record 9 of Set 10 | barranca
# Processing Record 10 of Set 10 | krasnoshchekovo
# Processing Record 11 of Set 10 | plettenberg bay
# Processing Record 12 of Set 10 | port shepstone
# Processing Record 13 of Set 10 | laguna
# Processing Record 14 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 10 | tanda
# Processing Record 16 of Set 10 | tursunzoda
# Processing Record 17 of Set 10 | camacha
# Processing Record 18 of Set 10 | domoni
# Processing Record 19 of Set 10 | gabu
# Processing Record 20 of Set 10 | altamirano
# Processing Record 21 of Set 10 | kalawit
# Processing Record 22 of Set 10 | leningradskiy
# Processing Record 23 of Set 10 | kruisfontein
# Processing Record 24 of Set 10 | elk city
# Processing Record 25 of Set 10 | bubaque
# Processing Record 26 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 27 of Set 10 | benito juarez
# Processing Record 28 of Set 10 | dubbo
# Processing Record 29 of Set 10 | dolores
# Processing Record 30 of Set 10 | amuntai
# Processing Record 31 of Set 10 | ankazoabo
# Processing Record 32 of Set 10 | katiola
# Processing Record 33 of Set 10 | westport
# Processing Record 34 of Set 10 | hami
# Processing Record 35 of Set 10 | ambon
# Processing Record 36 of Set 10 | sosnogorsk
# Processing Record 37 of Set 10 | kalabo
# Processing Record 38 of Set 10 | mehendiganj
# Processing Record 39 of Set 10 | oriximina
# Processing Record 40 of Set 10 | grindavik
# Processing Record 41 of Set 10 | key west
# Processing Record 42 of Set 10 | vaitape
# Processing Record 43 of Set 10 | fort-shevchenko
# Processing Record 44 of Set 10 | kenora
# Processing Record 45 of Set 10 | siaya
# Processing Record 46 of Set 10 | tadine
# Processing Record 47 of Set 10 | douglas
# Processing Record 48 of Set 10 | walvis bay
# Processing Record 49 of Set 10 | vanimo
# Processing Record 50 of Set 10 | kenai
# Processing Record 1 of Set 11 | bandarbeyla
# Processing Record 2 of Set 11 | itarema
# Processing Record 3 of Set 11 | qandahar
# City not found. Skipping...
# Processing Record 4 of Set 11 | jalu
# Processing Record 5 of Set 11 | santa cruz de tenerife
# Processing Record 6 of Set 11 | takoradi
# Processing Record 7 of Set 11 | isangel
# Processing Record 8 of Set 11 | tabuk
# Processing Record 9 of Set 11 | huarmey
# Processing Record 10 of Set 11 | ipixuna
# Processing Record 11 of Set 11 | jasper
# Processing Record 12 of Set 11 | leshan
# Processing Record 13 of Set 11 | mindelo
# Processing Record 14 of Set 11 | buchanan
# Processing Record 15 of Set 11 | villamontes
# Processing Record 16 of Set 11 | cockburn town
# Processing Record 17 of Set 11 | rong kwang
# Processing Record 18 of Set 11 | burica
# City not found. Skipping...
# Processing Record 19 of Set 11 | puerto escondido
# Processing Record 20 of Set 11 | ypsonas
# Processing Record 21 of Set 11 | thonon-les-bains
# Processing Record 22 of Set 11 | bayamo
# Processing Record 23 of Set 11 | tamiahua
# Processing Record 24 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 11 | sambava
# Processing Record 26 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 27 of Set 11 | jacareacanga
# Processing Record 28 of Set 11 | kisangani
# Processing Record 29 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 30 of Set 11 | concordia
# Processing Record 31 of Set 11 | killybegs
# Processing Record 32 of Set 11 | okha
# Processing Record 33 of Set 11 | mananara
# Processing Record 34 of Set 11 | khani
# Processing Record 35 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 36 of Set 11 | rosarito
# Processing Record 37 of Set 11 | dickinson
# Processing Record 38 of Set 11 | dali
# Processing Record 39 of Set 11 | at-bashi
# Processing Record 40 of Set 11 | kiruna
# Processing Record 41 of Set 11 | diamantino
# Processing Record 42 of Set 11 | san fernando
# Processing Record 43 of Set 11 | oktyabrskiy
# Processing Record 44 of Set 11 | cortland
# Processing Record 45 of Set 11 | druzhba
# Processing Record 46 of Set 11 | severnoye
# Processing Record 47 of Set 11 | austin
# Processing Record 48 of Set 11 | chapais
# Processing Record 49 of Set 11 | saint-georges
# Processing Record 50 of Set 11 | saint andrews
# Processing Record 1 of Set 12 | jiwani
# Processing Record 2 of Set 12 | bam
# Processing Record 3 of Set 12 | panaba
# Processing Record 4 of Set 12 | hambantota
# Processing Record 5 of Set 12 | katherine
# Processing Record 6 of Set 12 | newburyport
# Processing Record 7 of Set 12 | pangody
# Processing Record 8 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 12 | deputatskiy
# Processing Record 10 of Set 12 | mandalgovi
# Processing Record 11 of Set 12 | tommot
# Processing Record 12 of Set 12 | ponte nova
# Processing Record 13 of Set 12 | kununurra
# Processing Record 14 of Set 12 | broome
# Processing Record 15 of Set 12 | laukaa
# Processing Record 16 of Set 12 | lyuban
# Processing Record 17 of Set 12 | hay river
# Processing Record 18 of Set 12 | ponta delgada
# Processing Record 19 of Set 12 | dejen
# Processing Record 20 of Set 12 | truth or consequences
# Processing Record 21 of Set 12 | obregon
# Processing Record 22 of Set 12 | mikhaylovsk
# Processing Record 23 of Set 12 | arlit
# Processing Record 24 of Set 12 | guerrero negro
# Processing Record 25 of Set 12 | mersin
# Processing Record 26 of Set 12 | nea stira
# Processing Record 27 of Set 12 | sao miguel do araguaia
# Processing Record 28 of Set 12 | amapa
# Processing Record 29 of Set 12 | lewisporte
# Processing Record 30 of Set 12 | sur
# Processing Record 31 of Set 12 | jizan
# Processing Record 32 of Set 12 | bardiyah
# Processing Record 33 of Set 12 | chatham
# Processing Record 34 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 12 | slave lake
# Processing Record 36 of Set 12 | pokaran
# Processing Record 37 of Set 12 | qujing
# Processing Record 38 of Set 12 | carutapera
# Processing Record 39 of Set 12 | ukiah
# Processing Record 40 of Set 12 | moa
# Processing Record 41 of Set 12 | kargat
# Processing Record 42 of Set 12 | riesa
# Processing Record 43 of Set 12 | bulungu
# Processing Record 44 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 12 | newtonmore
# Processing Record 46 of Set 12 | isiro
# Processing Record 47 of Set 12 | lavumisa
# Processing Record 48 of Set 12 | yamada
# Processing Record 49 of Set 12 | paracuru
# Processing Record 50 of Set 12 | batemans bay
# Processing Record 1 of Set 13 | shingu
# Processing Record 2 of Set 13 | ferrol
# Processing Record 3 of Set 13 | semey
# Processing Record 4 of Set 13 | cottonwood
# Processing Record 5 of Set 13 | malazgirt
# Processing Record 6 of Set 13 | morristown
# Processing Record 7 of Set 13 | dudinka
# Processing Record 8 of Set 13 | alugan
# Processing Record 9 of Set 13 | norfolk
# Processing Record 10 of Set 13 | ocala
# Processing Record 11 of Set 13 | skjervoy
# Processing Record 12 of Set 13 | kathu
# Processing Record 13 of Set 13 | bimbo
# Processing Record 14 of Set 13 | solnechnyy
# Processing Record 15 of Set 13 | luganville
# Processing Record 16 of Set 13 | mozarlandia
# Processing Record 17 of Set 13 | cayenne
# Processing Record 18 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 13 | alihe
# Processing Record 20 of Set 13 | mayo
# Processing Record 21 of Set 13 | balad
# Processing Record 22 of Set 13 | darhan
# Processing Record 23 of Set 13 | gidam
# Processing Record 24 of Set 13 | cortez
# Processing Record 25 of Set 13 | barao de melgaco
# Processing Record 26 of Set 13 | kailua
# Processing Record 27 of Set 13 | chengmai
# City not found. Skipping...
# Processing Record 28 of Set 13 | shirokiy
# Processing Record 29 of Set 13 | manggar
# Processing Record 30 of Set 13 | umaria
# Processing Record 31 of Set 13 | leshukonskoye
# Processing Record 32 of Set 13 | poum
# Processing Record 33 of Set 13 | damaturu
# Processing Record 34 of Set 13 | hengyang
# Processing Record 35 of Set 13 | kolpashevo
# Processing Record 36 of Set 13 | santona
# Processing Record 37 of Set 13 | aksu
# Processing Record 38 of Set 13 | wolfsburg
# Processing Record 39 of Set 13 | dharchula
# Processing Record 40 of Set 13 | stornoway
# Processing Record 41 of Set 13 | okakarara
# Processing Record 42 of Set 13 | ahuimanu
# Processing Record 43 of Set 13 | lakes entrance
# Processing Record 44 of Set 13 | korla
# Processing Record 45 of Set 13 | roebourne
# Processing Record 46 of Set 13 | capao da canoa
# Processing Record 47 of Set 13 | french harbor
# Processing Record 48 of Set 13 | maumelle
# Processing Record 49 of Set 13 | krasnoselkup
# Processing Record 50 of Set 13 | sorland
# Processing Record 1 of Set 14 | invermere
# Processing Record 2 of Set 14 | toropets
# Processing Record 3 of Set 14 | pacifica
# Processing Record 4 of Set 14 | bonavista
# Processing Record 5 of Set 14 | northampton
# Processing Record 6 of Set 14 | mount dora
# Processing Record 7 of Set 14 | praxedis guerrero
# Processing Record 8 of Set 14 | progreso
# Processing Record 9 of Set 14 | tautira
# Processing Record 10 of Set 14 | fereydun kenar
# Processing Record 11 of Set 14 | urman
# Processing Record 12 of Set 14 | palasbari
# Processing Record 13 of Set 14 | slidell
# Processing Record 14 of Set 14 | hiriyur
# Processing Record 15 of Set 14 | fort dodge
# Processing Record 16 of Set 14 | bayji
# Processing Record 17 of Set 14 | urgut
# Processing Record 18 of Set 14 | lanzhou
# Processing Record 19 of Set 14 | kilifarevo
# Processing Record 20 of Set 14 | jinchang
# Processing Record 21 of Set 14 | nybro
# Processing Record 22 of Set 14 | kutum
# Processing Record 23 of Set 14 | macklin
# Processing Record 24 of Set 14 | golyshmanovo
# Processing Record 25 of Set 14 | puerto narino
# Processing Record 26 of Set 14 | ambilobe
# Processing Record 27 of Set 14 | vao
# Processing Record 28 of Set 14 | kenitra
# Processing Record 29 of Set 14 | yanam
# Processing Record 30 of Set 14 | berbera
# Processing Record 31 of Set 14 | serov
# Processing Record 32 of Set 14 | clyde river
# Processing Record 33 of Set 14 | bijie
# Processing Record 34 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 35 of Set 14 | zhicheng
# Processing Record 36 of Set 14 | alexandria
# Processing Record 37 of Set 14 | muisne
# Processing Record 38 of Set 14 | wahpeton
# Processing Record 39 of Set 14 | okitipupa
# Processing Record 40 of Set 14 | coihaique
# Processing Record 41 of Set 14 | andenes
# Processing Record 42 of Set 14 | banos
# Processing Record 43 of Set 14 | knysna
# Processing Record 44 of Set 14 | puerto ayacucho
# Processing Record 45 of Set 14 | turtas
# Processing Record 46 of Set 14 | port macquarie
# Processing Record 47 of Set 14 | santa cruz del sur
# Processing Record 48 of Set 14 | nelson bay
# Processing Record 49 of Set 14 | parintins
# Processing Record 50 of Set 14 | shimanovsk
# Processing Record 1 of Set 15 | marienburg
# Processing Record 2 of Set 15 | novaya bryan
# Processing Record 3 of Set 15 | oranjemund
# Processing Record 4 of Set 15 | uni
# Processing Record 5 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 15 | marzuq
# Processing Record 7 of Set 15 | ciudad bolivar
# Processing Record 8 of Set 15 | kerchevskiy
# Processing Record 9 of Set 15 | karpathos
# Processing Record 10 of Set 15 | banyo
# Processing Record 11 of Set 15 | hailar
# Processing Record 12 of Set 15 | gulabpura
# Processing Record 13 of Set 15 | yuanping
# Processing Record 14 of Set 15 | camaqua
# Processing Record 15 of Set 15 | te anau
# Processing Record 16 of Set 15 | korem
# Processing Record 17 of Set 15 | puerto vallarta
# Processing Record 18 of Set 15 | svetlyy
# Processing Record 19 of Set 15 | belmonte
# Processing Record 20 of Set 15 | kawalu
# Processing Record 21 of Set 15 | mount pleasant
# Processing Record 22 of Set 15 | phonhong
# Processing Record 23 of Set 15 | stournaraiika
# City not found. Skipping...
# Processing Record 24 of Set 15 | adoni
# Processing Record 25 of Set 15 | sharjah
# Processing Record 26 of Set 15 | matagami
# Processing Record 27 of Set 15 | artyk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 672

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Newport  51.5877   -2.9984     55.94        79           0
# 1       Mataura -46.1927  168.8643     37.47        89         100
# 2       Ushuaia -54.8000  -68.3000     51.46        43          40
# 3      Phillaur  31.0292   75.7842     75.13        57           0
# 4          Chuy -33.6971  -53.4616     63.72        67          90
# 5        Viedma -40.8135  -62.9967     73.51        24          19
# 6  Punta Arenas -53.1500  -70.9167     53.71        43          75
# 7      Thompson  55.7435  -97.8558     32.16        69          75
# 8     Jamestown  42.0970  -79.2353     67.05        45           0
# 9          Ocos  14.5094  -92.1933     83.23        72         100
#
#    Wind Speed Country Current Description
# 0       20.02      GB           clear sky
# 1        8.08      NZ     overcast clouds
# 2       11.50      AR    scattered clouds
# 3        7.05      IN           clear sky
# 4       13.53      UY     overcast clouds
# 5       15.30      AR          few clouds
# 6       16.11      CL       broken clouds
# 7       18.41      CA       broken clouds
# 8       11.50      US           clear sky
# 9        4.99      GT     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order =["City", "Country", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Newport      GB  51.5877   -2.9984     55.94        79           0
# 1       Mataura      NZ -46.1927  168.8643     37.47        89         100
# 2       Ushuaia      AR -54.8000  -68.3000     51.46        43          40
# 3      Phillaur      IN  31.0292   75.7842     75.13        57           0
# 4          Chuy      UY -33.6971  -53.4616     63.72        67          90
# 5        Viedma      AR -40.8135  -62.9967     73.51        24          19
# 6  Punta Arenas      CL -53.1500  -70.9167     53.71        43          75
# 7      Thompson      CA  55.7435  -97.8558     32.16        69          75
# 8     Jamestown      US  42.0970  -79.2353     67.05        45           0
# 9          Ocos      GT  14.5094  -92.1933     83.23        72         100
#
#    Wind Speed Current Description
# 0       20.02           clear sky
# 1        8.08     overcast clouds
# 2       11.50    scattered clouds
# 3        7.05           clear sky
# 4       13.53     overcast clouds
# 5       15.30          few clouds
# 6       16.11       broken clouds
# 7       18.41       broken clouds
# 8       11.50           clear sky
# 9        4.99     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name

output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
